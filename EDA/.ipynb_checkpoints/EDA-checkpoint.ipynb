# %% [markdown]
# <p style="
#     background: linear-gradient(90deg, #ff9a9e, #fad0c4, #fbc2eb, #a6c1ee);
#     font-size: 48px;
#     font-weight: bold;
#     color: white;
#     padding: 20px;
#     text-align: center;
#     border-radius: 15px;
#     animation: rainbow 5s linear infinite;
# ">
# ✨ Exploratory Data Analysis (EDA) ✨
# </p>
#
# <style>
# @keyframes rainbow {
#   0% { background-position: 0% 50%; }
#   50% { background-position: 100% 50%; }
#   100% { background-position: 0% 50%; }
# }
#
# p {
#   background-size: 400% 400%;
# }
# </style>

# %% [markdown]
# ## 🌆 Beijing Air Quality Dataset (2013–2017) — Column Descriptions
#
# This dataset contains **hourly air pollution measurements** collected from multiple monitoring stations across **Beijing, China**, spanning 5 years from **2013 to 2017**.
# Each row represents one hourly observation, including both **air quality indicators** and **meteorological conditions**.
#
# | **Column** | **Description** |
# |-------------|-----------------|
# | **No** | Sequential observation number — a unique identifier for each hourly record. |
# | **year** | Year of the observation (ranging from **2013 to 2017**). |
# | **month** | Month of the recorded observation (1–12). |
# | **day** | Day of the month when the observation was taken. |
# | **hour** | Hour of the day (0–23) indicating the measurement time. |
# | **PM2.5** | Concentration of fine particulate matter smaller than 2.5 µm in diameter (µg/m³).
# | **PM10** | Concentration of particulate matter smaller than 10 µm (µg/m³), often representing dust and larger particles in the air. |
# | **SO₂** | Sulfur dioxide concentration (µg/m³). Emitted from coal burning and industrial activities
# | **NO₂** | Nitrogen dioxide concentration (µg/m³). Commonly generated by traffic emissions and contributes to smog formation. |
# | **CO** | Carbon monoxide concentration (mg/m³). A toxic gas produced by incomplete combustion processes. |
# | **O₃** | Ozone concentration (µg/m³). A secondary pollutant formed through photochemical reactions involving NO₂ and volatile organic compounds. |
# | **TEMP** | Ambient air temperature (°C) recorded at the observation time. |
# | **PRES** | Atmospheric pressure (hPa). Helps analyze pollutant dispersion and weather influence. |
# | **DEWP** | Dew point temperature (°C), representing the level of moisture in the air. |
# | **RAIN** | Precipitation (mm) recorded during the observation period. |
# | **wd** | Wind direction (e.g., 'N', 'NE', 'SW'), indicating where the wind is blowing from. |
# | **WSPM** | Wind speed (m/s). Stronger winds can help disperse pollutants and improve air quality. |
# | **station** | Name of the monitoring station (e.g., Aotizhongxin, Tiantan, Wanliu, etc.). |

# %%
#Import librairies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math 
import warnings
warnings.filterwarnings("ignore") 
import plotly.graph_objects as go
import plotly.express as px
import missingno as msno

# %%
#import data
data = pd.read_csv(
    'C:/Users/Mega-Pc/Freelance/Air Quality Prediction and Alert System/data/raw/air_quality_data.csv',encoding='ISO-8859-1')

# %%
data
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 420763  35060  2017      2   28    19   11.0  32.0   3.0  24.0  400.0  72.0
# 420764  35061  2017      2   28    20   13.0  32.0   3.0  41.0  500.0  50.0
# 420765  35062  2017      2   28    21   14.0  28.0   4.0  38.0  500.0  54.0
# 420766  35063  2017      2   28    22   12.0  23.0   4.0  30.0  400.0  59.0
# 420767  35064  2017      2   28    23   13.0  19.0   4.0  38.0  600.0  49.0
#
# ...

# %%
data.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
data.tail()
# Out:
#            No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 420763  35060  2017      2   28    19   11.0  32.0  3.0  24.0  400.0  72.0
# 420764  35061  2017      2   28    20   13.0  32.0  3.0  41.0  500.0  50.0
# 420765  35062  2017      2   28    21   14.0  28.0  4.0  38.0  500.0  54.0
# 420766  35063  2017      2   28    22   12.0  23.0  4.0  30.0  400.0  59.0
# 420767  35064  2017      2   28    23   13.0  19.0  4.0  38.0  600.0  49.0
#
#         TEMP    PRES  DEWP  RAIN   wd  WSPM        station
# 420763  12.5  1013.5 -16.2   0.0   NW   2.4  Wanshouxigong
# 420764  11.6  1013.6 -15.1   0.0  WNW   0.9  Wanshouxigong
# 420765  10.8  1014.2 -13.3   0.0   NW   1.1  Wanshouxigong
# 420766  10.5  1014.4 -12.9   0.0  NNW   1.2  Wanshouxigong
# 420767   8.6  1014.1 -15.9   0.0  NNE   1.3  Wanshouxigong

# %%
# the dimensions of the dataset
print('Dimensions of the dataset:',data.shape)
# Out:
# Dimensions of the dataset: (420768, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.8+ MB

# %%
# Statistical overview of the numerical features in the train dataset
data.describe().transpose()
# Out:
#           count          mean           std        min      25%      50%  \
# No     420768.0  17532.500000  10122.116943     1.0000  8766.75  17532.5
# year   420768.0   2014.662560      1.177198  2013.0000  2014.00   2015.0
# month  420768.0      6.522930      3.448707     1.0000     4.00      7.0
# day    420768.0     15.729637      8.800102     1.0000     8.00     16.0
# hour   420768.0     11.500000      6.922195     0.0000     5.75     11.5
# PM2.5  412029.0     79.793428     80.822391     2.0000    20.00     55.0
# PM10   414319.0    104.602618     91.772426     2.0000    36.00     82.0
# SO2    411747.0     15.830835     21.650603     0.2856     3.00      7.0
# NO2    408652.0     50.638586     35.127912     1.0265    23.00     43.0
# CO     400067.0   1230.766454   1160.182716   100.0000   500.00    900.0
# O3     407491.0     57.372271     56.661607     0.2142    11.00     45.0
# TEMP   420370.0     13.538976     11.436139   -19.9000     3.10     14.5
# ...

# %%
# missing values in train dataset
missing_values = data.isnull().sum()
missing_percentage = data.isnull().sum() * 100 / len(data)
missing_data = pd.DataFrame({'missing_sum': missing_values, 'missing_percentage': missing_percentage})

fig = px.bar(missing_data.sort_values('missing_percentage', ascending=False), 
             x=missing_data.sort_values('missing_percentage', ascending=False).index,
             y='missing_percentage',
             title='Missing Values Percentage per Feature',
             labels={'index': 'Features', 'missing_percentage': 'Percentage of Missing Values (%)'},
             color='missing_percentage',
             color_continuous_scale='Viridis')


fig.update_layout(xaxis_tickangle=-45, 
                  xaxis_title='Features', 
                  yaxis_title='Percentage of Missing Values (%)')


fig.show()

# %%
# A visualization that shows the presence= white and absence =black of missing values
msno.matrix(data)
plt.show()

# %% [markdown]
# > 🕵️ **Remark:**
# > Columns "CO","O3","PM2.5","SO2","PM10" have missing values.
